# %% [markdown]
# # 💻 **Evidencia 2**
#
# ![tecmi.png](data:image/png;base64,...)

# %% [markdown]
# ## **Aplicaciones avanzadas en ciencia de datos**
#
# - Alumno: Carlos David Duarte Gill
# - Matricula: 7089642
# - Correo: AL07089642@tecmilenio.mx
# - Profesor: Martín Antonio Santos Romero
# - Fecha:  domingo 19 de abril de 2026
#
# *Cursando la Maestría en Gestión de Tecnologías de la Información*

# %% [markdown]
# # 📘 Introducción a la Evidencia 2

# %% [markdown]
# La presente Evidencia Final marca el final del proyecto de análisis desarrollado para NovaCredit Solutions, después de haber diseñado, implementado y evaluado un pipeline de Machine Learning para la predicción del riesgo de default, esta etapa representa la traducción del trabajo técnico realizado en las actividades pasadas en el posible impacto financiero, la mitigación de riesgos y las estrategias más convenientes para combatir el riesgo de default en Novacredit.
#
# A través de una narrativa comprensible, en esta evidencia final se expone cómo la ciencia de datos puede facilitar la toma de decisiones bien informadas, enfocándose en el impacto real y el beneficio para la organización.

# %% [markdown]
# ## 🗽 Alcance de la Evidencia 2
#
# El alcance de esta evidencia se concentra en la interpretación y comunicación de los resultados obtenidos durante las actividades pasadas integrando un resumen de los principales hallazgos logrados, la lectura ejecutiva de las métricas y patrones de riesgo identificados, así como la presentación de visualizaciones importantes y recomendaciones coherentes desde una visión de negocio sobre el caso.
# En palabras clave, la Evidencia Final fungirá como una puerta de enlace entre el análisis de datos y la estrategia empresarial para para NovaCredit Solutions.

# %% [markdown]
# # 📖 Síntesis del problema y la solución

# %% [markdown]
# ## 📝 Problema de negocio de NovaCredit
#
# NovaCredit Solutions enfrenta un problema muy grave para mantener su salud financiera debido a una tasa de morosidad históricamente cercana al 76% en la totalidad de su cartera de clientes. Y, debido a esta situación, la rentabilidad y la liquidez del negocio se ha visto impactada negativamente, todo esto como resultado de un modelo de gestión de riesgo principalmente reactivo, que identifica los problemas cuando el capital ya se encuentra en riesgo o incluso ya perdido.
#
# NovaCredit es victima de una falta de visión anticipada sobre el comportamiento de sus clientes, lo que ha permitido la acumulación de riesgos y pérdidas importantes para el negocio, limitando así el crecimiento seguro de nuevas líneas de crédito y la suma de nuevos clientes potencialmente seguros para el negocio. En este contexto, la organización necesita de manera urgente un enfoque analítico que le permita gestionar el problema del riesgo default de una forma preventiva y estratégica, con el objetivo de mejorar su capacidad de crecimiento sostenible a largo plazo.

# %% [markdown]
# ## 🏁 Objetivo del análisis
#
# El objetivo del análisis desarrollado durante las fases de este proyecto es transformar la gestión del riesgo crediticio en NovaCredit hacia un enfoque preventivo y estratégico, permitiendo anticiparse al incumplimiento de sus clientes antes de que estos generen pérdidas financieras.
#
# Un paso critico es identificar perfiles de clientes a través del análisis del comportamiento histórico de la cartera de clientes y gestionar grupos estratégicos para tomar decisiones más informadas sobre a que grupos de clientes proteger o limitar, alineando las políticas de crédito del negocio con el riesgo y el valor de cada grupo de clientes definido. Este enfoque permite trabajar sobre una gestión más eficiente del riesgo, orientada a proteger la rentabilidad y crecimiento del negocio.

# %% [markdown]
# ## 🧭 Enfoques analíticos utilizados
#
# Para enfrentar el problema del riesgo crediticio, se implementa un enfoque analítico integral que combina predicción, segmentación y control de la información, con el objetivo de mejorar la calidad de las decisiones antes de que los riesgos se conviertan en pérdidas financieras. Este enfoque permite identificar exitosamente a  clientes con alta probabilidad de incumplimiento, identificando grupos de comportamiento similares dentro de la cartera y detectando patrones atípicos de alto riesgo que requieran una atención temprana de alta prioridad. Adicionalmente, se incorpora un marco de transparencia que permite explicar y justificar cada decisión de crédito tomada, fortaleciendo el cumplimiento regulatorio.

# %% [markdown]
# ## 🔍 Principales hallazgos identificados
#
# El análisis revela que el alto nivel de morosidad de la cartera de clientes no es aleatorio, sino que es el resultado de patrones de comportamiento financiero identificables y repetibles que pueden atenderse con anticipación. Los resultados demuestran una favorable capacidad para prevenir pérdidas financieras, al proveer de las habilidades para detectar de forma temprana a la gran mayoría de los clientes que incurrirán en un incumplimiento crediticio y aplicar las acciones preventivas necesarias antes de que el capital de la empresa se vea comprometido. Asimismo, se identifican segmentos de clientes similares en cuestiones de riesgo y de valor para el negocio, incluyendo grupos de bajo riesgo y otros de alto impacto financiero. Cabe destacar que, un hallazgo clave es la identificación de una combinación de factores que prácticamente garantizan el incumplimiento por parte de los clientes, lo que incluso llega a justificar el uso de políticas automáticas de control de crédito para riesgos altamente tóxicos para la empresa.

# %% [markdown]
# # 💻 Desarrollo de la Evidencia 2

# %% [markdown]
# **A continuación:**
#
# 🧰 Se importan las librerías necesarias para el desarrollo de los modelos necesarios.
#
# 🔧 Se carga el dataset y se muestra una tabla descriptiva del dataset.

# %% [markdown]
# ## 🧰 Carga de todas las librerías necesarias

# %%
# ------------------------------------------------------------------------------
# LIBRERIAS
# ------------------------------------------------------------------------------
import sys
import os
# warnings
import warnings
import logging
warnings.filterwarnings('ignore')

try:
    # ------------------------------------------------------------------------------
    # liberias basicas
    # ------------------------------------------------------------------------------
    import pandas as pd
    import numpy as np

    # ------------------------------------------------------------------------------
    # visualizacion
    # ------------------------------------------------------------------------------
    import matplotlib.pyplot as plt
    import seaborn as sns
    from tabulate import tabulate
    import plotly
    import plotly.express as px
    import plotly.graph_objects as go


    # ------------------------------------------------------------------------------
    print("-" * 80)
    print("⚙️ Cargando librerías core...")
    print(f"Python: {sys.version.split()[0]}")
    print(f"Pandas version: {pd.__version__}")
    print(f"NumPy version: {np.__version__}")


    print("-" * 80)
    print("⚙️ Cargando librerías de visualización...")
    print(f"Matplotlib - version: {plt.matplotlib.__version__}")
    print(f"Seaborn version: {sns.__version__}")
    print(f"Plotly version: {plotly.__version__}")
    print("-" * 80)
    print("🚀 ¡Entorno preparado!")
    print("-" * 80)

except Exception as e:
    print(f"❌ Error de entorno, favor de instalar las dependencias necesarias: {e}")

warnings.filterwarnings('ignore')
# Out:
# --------------------------------------------------------------------------------
# ⚙️ Cargando librerías core...
# Python: 3.10.20
# Pandas version: 2.3.3
# NumPy version: 2.2.6
# --------------------------------------------------------------------------------
# ⚙️ Cargando librerías de visualización...
# Matplotlib - version: 3.10.8
# Seaborn version: 0.13.2
# Plotly version: 6.7.0
# --------------------------------------------------------------------------------
# 🚀 ¡Entorno preparado!
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 🗂 Funciones auxiliares

# %%
# --------------------------------------------------------------------------
# 🤖 display mensaje
# --------------------------------------------------------------------------
def display_mensaje(msj):
    print("\n" + "="*80)
    print("\033[1m --- " + msj + " --- \033[0m")
    print("="*80)

# %%
# ------------------------------------------------------------------------------
# 🤖 diccionario builder
# ------------------------------------------------------------------------------

def dictionary_builder(columnas_categoricas, msj):

    _dict_unique_values_ = {}

    # recorremos las columnas categoricas para obtener sus valores
    display_mensaje(msj)
    # recorreos las columnas categoricas
    for col in columnas_categoricas.columns:
        # obtenemos los vals unicos
        unique_values = columnas_categoricas[col].unique()
        # asignamos los valores unicos al dict
        _dict_unique_values_[col] = columnas_categoricas[col].unique()


    # para mostrar el resultado del diccionario en pantalla
    # convertimos el diccionario a un conjunto de listas
    data = [[key] + list(value) for key, value in _dict_unique_values_.items()]

    # definimos los titulos de la tabla
    headers = ["Columna"] + [f"Valor único {i+1}" for i in range(len(max(_dict_unique_values_.values(), key=len)))]
    # imprimiendo
    print(tabulate(data, headers=headers, tablefmt="grid"))

    return _dict_unique_values_;

# %% [markdown]
# ## 💾 Carga de los datos

# %% [markdown]
# Para iniciar el análisis se utiliza la url pública del dataset en **Canvas**.

# %%
# ------------------------------------------------------------------------------
# CARGA DEL DATASET
# ------------------------------------------------------------------------------
# URL pública del dataset
_URL_REPO_ = 'https://raw.githubusercontent.com/RamRider89/aplicaciones-ciencia-datos/refs/heads/main/actividades/actividad-2/novacredit_clientes_limpio.csv'
_URL_LOCAL_ = "./novacredit_clientes_limpio.csv"
_URL_ = _URL_LOCAL_
# config
pd.set_option('display.max_columns', None)

# leyendo el archivo csv mediante pandas
df_prep = pd.read_csv(_URL_)

# %% [markdown]
# # 📺 Visualización y comunicación de resultados

# %% [markdown]
# A continuación se presentan de manera visual los 8 principales hallazgos que resumen el comportamiento de riesgo, la estructura de la cartera de clientes y los factores que más influyen en el riesgo default.

# %% [markdown]
# ## 🗂 Configuración de estilos

# %%
# ------------------------------------------------------------------------------
# Colores
# ------------------------------------------------------------------------------
# colores tecmilenio
_color_tecmi_light="#26d07c"
_color_primary="#007bff"
_color_gray="#6c757d"
_color_white="#ffffff"
_color_danger="#ff0000"
_color_success="#28a745"
_color_info="#17a2b8"
_color_warning="#ffc107"

# Muted
_Gold_ = '#f0c571'
_Teal_ = '#59a89c'
_Blue_ = '#0b81a2'
_Red_ = '#e25759'
_Dark_Red_ = '#9d2c00'
_Purple_ = '#7E4794'
_Green_ = '#36b700'
_Gray_ = '#c8c8c8'

COLOR_RIESGO = '#E74C3C'
COLOR_SEGURO = '#95A5A6'
COLOR_TEXTO = '#2C3E50'

# paletas
_paleta_muted_ = [_Gold_, _Teal_, _Blue_, _Red_, _Dark_Red_, _Purple_, _Green_, _Gray_]
_paleta3_ = [_color_tecmi_light, _color_info, _color_warning]

# %%
# ------------------------------------------------------------------------------
# Configuración de estilos limpios
# ------------------------------------------------------------------------------
# configuración de estilo visual
plt.style.use('default')
sns.set_theme(style="whitegrid")
sns.set_style("white")

# %%
df_viz = df_prep.copy()

# %% [markdown]
# ## 📶 Distribución de Exposición al Riesgo

# %% [markdown]
# Uso del Gráfico de Donas para mostrar que el problema abarca tanto a las personas como al dinero.

# %%
# ------------------------------------------------------------------------------
# HALLAZGO 1: La Gravedad del Problema Actual (Gráficos de Donas)
# ------------------------------------------------------------------------------
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Distribución de Exposición al Riesgo Sistémico', fontsize=16, fontweight='bold', color=COLOR_TEXTO, y=1.05)

# Datos: Conteo de Clientes vs Volumen de Capital
clientes_riesgo = df_viz['prediccion_default'].value_counts(normalize=True)
capital_riesgo = df_viz.groupby('prediccion_default')['saldo_promedio'].sum() / df_viz['saldo_promedio'].sum()

labels = ['Al Corriente', 'Riesgo de Default']
colores = [COLOR_SEGURO, COLOR_RIESGO]

# Dona 1: Clientes
ax1.pie(clientes_riesgo, labels=labels, autopct='%1.1f%%', startangle=90, colors=colores, 
        wedgeprops=dict(width=0.4, edgecolor='w'), textprops={'fontsize': 11})
ax1.set_title('Porcentaje de Clientes', color=COLOR_TEXTO, fontweight='bold')

# Dona 2: Capital (Saldo)
ax2.pie(capital_riesgo, labels=labels, autopct='%1.1f%%', startangle=90, colors=colores, 
        wedgeprops=dict(width=0.4, edgecolor='w'), textprops={'fontsize': 11})
ax2.set_title('Exposición de Capital (Volumen)', color=COLOR_TEXTO, fontweight='bold')

plt.figtext(0.5, 0.01, "Insight: La morosidad no solo afecta a una gran cantidad de clientes (77%), sino que concentra casi el 80% del capital prestado.", 
            ha="center", fontsize=11, style='italic', color='#7F8C8D')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/apps-data/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prediccion_default'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 8
# ...

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 📶 El "Cóctel Tóxico" (Mapa de Calor)

# %% [markdown]
# Un Heatmap que demuestra exactamente bajo qué condiciones se dispara la probabilidad de pérdida.

# %%
# ------------------------------------------------------------------------------
# HALLAZGO 2: El Cóctel Tóxico (Mapa de Riesgo)
# ------------------------------------------------------------------------------
plt.figure(figsize=(8, 6))

# Agrupar utilización en rangos claros para los ejecutivos
df_viz['Rango_Utilizacion'] = pd.cut(df_viz['utilizacion_linea'], bins=[0, 0.4, 0.7, 0.9, 1.0], labels=['<40%', '40-70%', '70-90%', '>90%'])
pivot_riesgo = df_viz.pivot_table(values='prediccion_default', index='pagos_atrasados', columns='Rango_Utilizacion', aggfunc='mean')

# Crear el Heatmap
ax = sns.heatmap(pivot_riesgo, annot=True, fmt=".0%", cmap="Reds", cbar=False, 
                 annot_kws={"size": 12, "weight": "bold"}, linewidths=.5)

plt.title('Probabilidad de Default: Utilización vs. Atrasos', fontsize=14, fontweight='bold', pad=20, color=COLOR_TEXTO)
plt.xlabel('Utilización de la Línea de Crédito', fontweight='bold', labelpad=10)
plt.ylabel('Número de Pagos Atrasados', fontweight='bold', labelpad=10)

plt.figtext(0.5, -0.05, "Insight: Utilizar más del 70% de la línea combinado con 2+ atrasos garantiza matemáticamente el Default (>88%).", 
            ha="center", fontsize=11, style='italic', color='#7F8C8D')
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## Hallazgo 3 y 4: Importancia de Variables y Segmentación

# %% [markdown]
# Gráficos de barras limpios. Nota cómo eliminamos los bordes superior y derecho (despine) para dar un aspecto moderno.

# %%
# ------------------------------------------------------------------------------
# HALLAZGO 3 y 4: Motores de Morosidad y Segmentación Conductual
# ------------------------------------------------------------------------------
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# --- Gráfico Izquierdo: SHAP / Importancia Simulada ---
variables = ['Utilización de Crédito', 'Pagos Atrasados', 'Saldo Promedio', 'Ingreso Mensual', 'Edad']
impacto = [0.35, 0.25, 0.15, 0.08, 0.02] # Valores ilustrativos de SHAP

ax1.barh(variables[::-1], impacto[::-1], color=['#BDC3C7', '#BDC3C7', COLOR_RIESGO, COLOR_RIESGO, COLOR_RIESGO][::-1])
ax1.set_title('Factores que Detonan la Decisión (Importancia SHAP)', fontweight='bold', color=COLOR_TEXTO)
ax1.set_xlabel('Impacto en la Probabilidad de Riesgo')
sns.despine(ax=ax1)

# --- Gráfico Derecho: Segmentación al 100% ---
crosstab_seg = pd.crosstab(df_viz['Segmento'], df_viz['prediccion_default'], normalize='index') * 100
# Reordenar para que Apalancados Crónicos esté arriba
orden_segmentos = ['Apalancados Crónicos', 'VIP Volátiles', 'Inactivos Bajo Límite', 'Leales Estabilizados']
crosstab_seg = crosstab_seg.reindex(orden_segmentos)

crosstab_seg.plot(kind='barh', stacked=True, color=[COLOR_SEGURO, COLOR_RIESGO], ax=ax2, legend=False)
ax2.set_title('Composición de Riesgo por Segmento Conductual', fontweight='bold', color=COLOR_TEXTO)
ax2.set_ylabel('')
ax2.set_xlabel('Porcentaje de la Cartera (%)')
sns.despine(ax=ax2)

# Añadir leyenda ejecutiva personalizada
import matplotlib.patches as mpatches
riesgo_patch = mpatches.Patch(color=COLOR_RIESGO, label='Pérdida Esperada (Default)')
seguro_patch = mpatches.Patch(color=COLOR_SEGURO, label='Cartera Sana')
fig.legend(handles=[riesgo_patch, seguro_patch], loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.05), frameon=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## Hallazgo 5: El Peligro Oculto (Anomalías Isolation Forest)

# %% [markdown]
# El uso del color Gris vs Rojo permite al ejecutivo ver instantáneamente que "lo rojo no pertenece ahí".

# %%
# ------------------------------------------------------------------------------
# HALLAZGO 5: Exposición Crítica en Clientes Atípicos (Outliers)
# ------------------------------------------------------------------------------
plt.figure(figsize=(10, 6))

# Separar datos para darles formato distinto
normales = df_viz[df_viz['Es_Anomalia'] == 'Normal']
anomalias = df_viz[df_viz['Es_Anomalia'] == 'Atípico']

# Plot de normales (Gris transparente, no llaman la atención)
plt.scatter(normales['ingreso_mensual'], normales['saldo_promedio'], 
            c=COLOR_SEGURO, alpha=0.3, label='Comportamiento Estándar', s=30)

# Plot de anomalías (Rojo intenso, grandes, borde negro)
plt.scatter(anomalias['ingreso_mensual'], anomalias['saldo_promedio'], 
            c=COLOR_RIESGO, alpha=0.9, edgecolors='black', label='Exposición Atípica (Outliers)', s=80, marker='D')

plt.title('Identificación de Fraude y Riesgo Atípico (Isolation Forest)', fontsize=14, fontweight='bold', color=COLOR_TEXTO, pad=15)
plt.xlabel('Ingreso Mensual del Cliente ($)', fontweight='bold')
plt.ylabel('Saldo Promedio Acumulado ($)', fontweight='bold')
plt.legend(frameon=True, shadow=True)
sns.despine()

plt.figtext(0.5, -0.05, "Insight: El 5% de la cartera presenta saldos injustificados frente a sus ingresos. Requiere bloqueo y auditoría manual.", 
            ha="center", fontsize=11, style='italic', color='#7F8C8D')
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## Hallazgo 6: Retorno de Inversión (Plotly Waterfall)

# %% [markdown]
# Para hablar de dinero, usamos Plotly. El gráfico de cascada es el estándar de oro en las juntas directivas financieras para mostrar el "Puente" (Bridge) entre la situación actual y la proyectada.

# %%
# ------------------------------------------------------------------------------
# HALLAZGO 6: ROI del Proyecto MLOps (Gráfico de Cascada / Waterfall)
# ------------------------------------------------------------------------------
# Datos financieros simulados para la proyección
perdida_proyectada = 5000000 # 5 Millones (Si no hacemos nada)
contencion_modelo = -4200000 # Lo que el modelo (87.8% Recall) nos salva bloqueando a tiempo
costo_falsos_positivos = 300000 # Pérdida de interés por negar a buenos clientes por error
perdida_neta_final = perdida_proyectada + contencion_modelo + costo_falsos_positivos

fig = go.Figure(go.Waterfall(
    name="Proyección", orientation="v",
    measure=["relative", "relative", "relative", "total"],
    x=["Pérdida Inminente (Sin IA)", "Ahorro por Contención (Modelo IA)", "Costo Oportunidad (Falsos Positivos)", "Pérdida Neta Proyectada"],
    textposition="outside",
    # Formateo como dólares
    text=["-$5.0M", "+$4.2M", "-$0.3M", f"-${abs(perdida_neta_final)/1000000:.1f}M"],
    y=[-perdida_proyectada, abs(contencion_modelo), -costo_falsos_positivos, -perdida_neta_final],
    connector={"line":{"color":"rgb(63, 63, 63)"}},
    decreasing={"marker":{"color": COLOR_RIESGO}}, # Rojo para pérdidas
    increasing={"marker":{"color": "#2ECC71"}},    # Verde para ahorros
    totals={"marker":{"color": "#34495E"}}         # Azul oscuro para total final
))

fig.update_layout(
    title=dict(text="Impacto Financiero del Pipeline de Riesgo (ROI)", font=dict(size=18, color=COLOR_TEXTO)),
    showlegend=False,
    plot_bgcolor='white',
    yaxis=dict(title="Millones de Dólares (USD)", showticklabels=False), # Ocultamos el eje Y para que lean los números de las barras
    width=900, height=500
)

# Línea base en cero
fig.add_hline(y=0, line_width=1, line_color="black")

fig.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 📈 2. Capacidad del modelo para separar riesgo (Curva ROC)

# %% [markdown]
# 📌 Mensaje ejecutivo: el modelo es confiable para decisiones automatizadas.

# %%
# ---------------------------------------
# HALLAZGO 2: El modelo distingue riesgo real
# ---------------------------------------

from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, _ = roc_curve(y_test, y_proba)
auc_value = roc_auc_score(y_test, y_proba)

plt.figure(figsize=(6,5))

plt.plot(
    fpr, tpr,
    color='#0b81a2',
    linewidth=2,
    label=f'Modelo (AUC = {auc_value:.2f})'
)

# Línea base
plt.plot([0,1], [0,1], linestyle='--', color='#c8c8c8')

plt.title(
    "El modelo separa clientes de alto y bajo riesgo con alta precisión",
    fontsize=14,
    fontweight='bold'
)

plt.xlabel("Falsos positivos")
plt.ylabel("Verdaderos positivos (Recall)")

plt.legend(frameon=False)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 🧮 3. Impacto operativo del modelo (Matriz de confusión)

# %% [markdown]
# 📌 Mensaje ejecutivo: el modelo protege capital sin castigar masivamente a buenos clientes.

# %%
# ---------------------------------------
# HALLAZGO 3: El modelo previene pérdidas reales
# ---------------------------------------

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    cbar=False
)

plt.title(
    "La mayoría de los clientes morosos son detectados a tiempo",
    fontsize=14,
    fontweight='bold'
)

plt.xlabel("Predicción del modelo")
plt.ylabel("Resultado real")
plt.xticks([0.5, 1.5], ['Al corriente', 'Default'])
plt.yticks([0.5, 1.5], ['Al corriente', 'Default'])

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 🧩 4. Tamaño de los segmentos estratégicos

# %% [markdown]
# 📌 Mensaje ejecutivo: el riesgo está concentrado, no distribuido.

# %%
# ---------------------------------------
# HALLAZGO 4: La cartera no es homogénea
# ---------------------------------------

segment_counts = df_prep['segmento_cliente'].value_counts().reset_index()
segment_counts.columns = ['segmento_cliente', 'clientes_riesgo']

plt.figure(figsize=(7,4))

sns.barplot(
    data=segment_counts,
    x='segmento_cliente',
    y='clientes_riesgo',
    palette='muted'
)

plt.title(
    "La mayor parte de los clientes se concentra en segmentos de alto riesgo",
    fontsize=14,
    fontweight='bold'
)

plt.xlabel("")
plt.ylabel("Número de clientes")

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 🔥 5. Tasa de default por segmento

# %% [markdown]
# 📌 Mensaje ejecutivo: una sola estrategia de riesgo está condenada a fallar.

# %%
# ---------------------------------------
# HALLAZGO 5: No todos los clientes deben tratarse igual
# ---------------------------------------

cluster_risk = (
    df_prep.groupby('segmento_cliente')['default_12m']
    .mean()
    .mul(100)
    .reset_index()
)

plt.figure(figsize=(7,4))

sns.barplot(
    data=cluster_risk,
    x='segmento_cliente',
    y='default_12m',
    palette=['#36b700', '#e25759', '#e25759', '#e25759']
)

plt.axhline(
    y=df_prep['default_12m'].mean()*100,
    linestyle='--',
    color='#6c757d',
    linewidth=1
)

plt.title(
    "Solo un segmento es financieramente saludable",
    fontsize=14,
    fontweight='bold'
)

plt.xlabel("")
plt.ylabel("Tasa de default (%)")

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 🧠 6. Variables que más influyen en el default

# %% [markdown]
# 📌 Mensaje ejecutivo: el riesgo se puede medir, no es subjetivo.

# %%
# ---------------------------------------
# HALLAZGO 6: El riesgo nace del comportamiento
# ---------------------------------------

importances = (
    pd.Series(
        model.feature_importances_,
        index=X_train_prep.columns
    )
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(7,5))

importances.sort_values().plot.barh(
    color='#0b81a2'
)

plt.title(
    "El incumplimiento se explica por patrones financieros, no por azar",
    fontsize=14,
    fontweight='bold'
)

plt.xlabel("Importancia relativa")
plt.ylabel("")

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## ⚠️ 7. Combinación crítica: Mora + Utilización

# %% [markdown]
# 📌 Mensaje ejecutivo: el riesgo está concentrado, no distribuido.

# %%
# ---------------------------------------
# HALLAZGO 7: Una señal temprana casi infalible
# ---------------------------------------

combo = (
    df_prep.groupby(['Mora_Alta', 'Utilizacion_Alta'])['default_12m']
    .mean()
    .mul(100)
    .reset_index()
)

plt.figure(figsize=(6,4))

sns.barplot(
    data=combo,
    x=combo.index,
    y='default_12m',
    palette=['#6c757d', '#6c757d', '#e25759', '#e25759']
)

plt.title(
    "Mora alta dispara el default casi al 100%",
    fontsize=14,
    fontweight='bold'
)

plt.ylabel("Probabilidad de default (%)")
plt.xlabel("Combinación de comportamiento")

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a

# %% [markdown]
# ## 🧩 4. Tamaño de los segmentos estratégicos

# %% [markdown]
# 📌 Mensaje ejecutivo: el riesgo está concentrado, no distribuido.

# %%
# ---------------------------------------
# HALLAZGO 4: La cartera no es homogénea
# ---------------------------------------

segment_counts = df_prep['segmento_cliente'].value_counts().reset_index()
segment_counts.columns = ['segmento_cliente', 'clientes_riesgo']

plt.figure(figsize=(7,4))

sns.barplot(
    data=segment_counts,
    x='segmento_cliente',
    y='clientes_riesgo',
    palette='muted'
)

plt.title(
    "La mayor parte de los clientes se concentra en segmentos de alto riesgo",
    fontsize=14,
    fontweight='bold'
)

plt.xlabel("")
plt.ylabel("Número de clientes")

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📃 Interpretación

# %% [markdown]
# a
